# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import random
import time

#credit -  https://scrapeops.io/web-scraping-playbook/403-forbidden-error-web-scraping/#:~:text=Getting%20a%20HTTP%20403%20Forbidden,be%20authorised%20to%20access%20it

def random_user_agent():
    user_agents_list = [
    'Mozilla/5.0 (Linux; Android 7.0; Lenovo TB-7304F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.101 Safari/537.36',
    'Mozilla/5.0 (Linux; Android 8.1.0; Lenovo TB-7104F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.119 Safari/537.36',
    'Mozilla/5.0 (Linux; Android 7.0; Lenovo TB-7304F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.116 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64; Trident/7.0; LCJB; rv:11.0) like Gecko',
    'Mozilla/5.0 (Linux; U; Android 4.4; ru-ru; Lenovo A7600-H Build/KRT16S) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.4 Mobile Safari/E7FBAF',
    'Mozilla/5.0 (Linux; Android 4.2.1; Lenovo P780 Build/JOP40D) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 YaBrowser/17.3.1.383.00 Mobile Safari/E7FBAF',
    'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; Touch; MALNJS; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0; Touch; MALNJS)',
    'Mozilla/5.0 (Linux; Android 4.4; Lenovo A7600-H Build/KRT16S) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.83 Mobile Safari/E7FBAF',
    'Mozilla/5.0 (Linux; Android 4.4.2; Lenovo A3500-FL Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.83 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64; Trident/7.0; MALNJS; rv:11.0) like Gecko',
    'Mozilla/5.0 (Linux; Android 4.4; Lenovo A3500-H Build/KRT16S) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.83 Mobile Safari/E7FBAF',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; Tablet PC 2.0; MALC)']
    return { "User-Agent" : random.choice(user_agents_list)}


url = 'https://www.realtor.com/realestateandhomes-search/Chicago_IL/'    
for j in range(1,5):
    

    response  = requests.get(url, headers= random_user_agent())
    print(response)
    soup = BeautifulSoup(response.text, "html.parser")
    data = soup.find('ul', attrs={'class':'jsx-343105667'})
    urls=[]
    for apart in data.find_all('a',attrs={'class':'jsx-1534613990'}):
        link ='http://realtor.com'+apart['href']
        urls.append(link)
    price=[]
    year_built=[]
    sqft=[]
    beds=[]
    bathroom=[]
    price_sqft=[]
    Property_Type=[]
    grage=[]
    HOA_Fees=[]
    Address =[]
    Time_On_Web=[]
    sqft_lot=[]    
    k=1
    for ur in urls:
        response2 = requests.get(ur, headers=random_user_agent())
        print(response2,k)
        k=k+1
        soup2 =BeautifulSoup(response2.text, "html.parser")
       
        data2 = soup2.find('div', attrs={'class':'listing-summary-info'})
        deats1 = soup2.find('ul', attrs={'class':'PropertyMetastyles__StyledPropertyMeta-rui__sc-1g5rdjn-0'})
       
        bed = data2.find('li', {'class':'PropertyBedMetastyles__StyledPropertyBedMeta-rui__a4nnof-0 EMhcO'})
        if bed != None:
            beds.append(bed.find("span").text)
        else:
            beds.append(None)
           
        bath = data2.find("li", {"class":"PropertyBathMetastyles__StyledPropertyBathMeta-rui__sc-67m6bo-0 kPVhSw"})
        if bath !=None:
            bathroom.append(bath.find("span").text)
        else:
            bathroom.append(None)
           
        sqftD = data2.find("li", {"class":"PropertySqftMetastyles__StyledPropertySqftMeta-rui__sc-1gdau7i-0 eucnnL"})
        if sqftD!=None:
            sqft.append(sqftD.find("span", {"class" : "meta-value"}).text)
        else:
            sqft.append(None)
           
        sqft_lotD = data2.find("li", {"class": "PropertyLotSizeMetastyles__StyledPropertyLotSizeMeta-rui__sc-1cz4zco-0 iGmjzN"})
        if sqft_lotD !=None:
            sqft_lot.append(sqft_lotD.find("span", {"class" : "meta-value"}).text)
        else:
            sqft_lot.append(None)
           
        price.append(data2.find('div', attrs={'class':'Price__Component-rui__x3geed-0'}).text)
        Address.append(data2.find('h1', attrs={'class':'Text__StyledText-rui__sc-19ei9fn-0'}).text)
       
        headers=[]
        attrib2=['Time on realtor.com','Property Type','HOA Fees','Price per sqftPrice per square feet','Garage','Year Built']
        deats=data2.find('ul', attrs={'class':'ListingKeyFactsstyles__StyledListingKeyFacts-rui__sc-196zwd6-0'})
       
        for det in deats.find_all('li',attrs={'ListingKeyFactItemstyles__StyledListingKeyFactItem-rui__sc-1txoqt4-0 iHoeZZ'}):    
             headers.append(det.find(class_='Text__StyledText-rui__sc-19ei9fn-0').text)
        a=[]
        for det in deats.find_all('div',attrs={'class':'Text__StyledText-rui__sc-19ei9fn-0 eXfzyb TypeBody__StyledBody-rui__sc-163o7f1-0 gVxVge'}):    
                a.append(det.text)
        dictv={}
        for i in range(len(a)):
            dictv[headers[i]]=a[i]
           
        for i in dictv:
            if i  in headers:
                if i == 'Property Type':
                    Property_Type.append(dictv[i])
                if i == 'Time on realtor.com':
                    Time_On_Web.append(dictv[i])
                if i == 'HOA Fees':
                    HOA_Fees.append(dictv[i])
                if i == 'Price per sqftPrice per square feet':
                    price_sqft.append(dictv[i])
                if i == 'Garage':
                    grage.append(dictv[i])
                if i == 'Year Built':                
                    year_built.append(dictv[i])
                   
        for i in attrib2:
            if i not in dictv.keys():
                if i == 'Property Type':
                    Property_Type.append(None)
                if i == 'Time on realtor.com':
                    Time_On_Web.append(None)
                if i == 'HOA Fees':
                    HOA_Fees.append(None)
                if i == 'Price per sqftPrice per square feet':
                    price_sqft.append(None)
                if i == 'Garage':
                    grage.append(None)
                if i == 'Year Built':                
                    year_built.append(None)
        time.sleep(5)            
    next_page_div = soup.find('div', attrs={'class':'Paginatorstyles__StyledPaginator-rui__sc-1prqz4y-0 lgzOLo'})
    print(j)
    next_page_a=next_page_div.find('a',{'aria-label':'Go to next page'})
    url='https://www.realtor.com'+ next_page_a['href']
    print(url)
    df=pd.DataFrame({"price":price,"year built":year_built, "sqft":sqft,"beds":beds,"bathroom":bathroom,
               "price_sqft":price_sqft, "Property_Type":Property_Type,"grage":grage,"HOA Fees":HOA_Fees,
               "Address":Address,"Time On Web":Time_On_Web,"sqft lot":sqft_lot})
    df.to_csv('npage-'+str[j]+'.csv')
    time.sleep(7)                  


print(df)

# %%
import pandas as pd
import os
import glob

#list of csv files
all_files = glob.glob(os.path.join(r"C:\Users\npages" ,"*.csv"))

#create empty dataframe
df_final = pd.DataFrame()
df_list=[]
#loop through list and append to dataframe
for filename in all_files:
    df = pd.read_csv(filename)
    df_list.append(df)

df_final = pd.concat(df_list,ignore_index=True) 
df_final.to_csv('np1-11.csv')

df_final

# %%
df_final1=pd.read_csv('all_pages.csv')
df_final2=pd.read_csv('np1-11.csv')
df_list = [df_final1, df_final2]
df_final3 = pd.concat(df_list,ignore_index=True)
df_final3.to_csv('all_new_pages.csv')
